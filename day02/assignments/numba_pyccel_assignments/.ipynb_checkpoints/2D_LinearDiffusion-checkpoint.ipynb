# %% [markdown]
# ## Imports

# %%
import numpy as np
from matplotlib import pyplot, cm
from mpl_toolkits.mplot3d import Axes3D
import time
from numba import njit
from pyccel.epyccel import epyccel
from pyccel.decorators import types

# %% [markdown]
# ## Pure python function

# %%
def solve_2d_diff_pure(u, un, nt, dt, dx, dy, nu):
    
    row, col = u.shape

    for n in range(nt):
        un = u.copy()
        for i in range(1, row-1): 
            for j in range(1,col-1):
                u[i,j] = un[i,j] + (nu * dt / dx**2) * (un[i+1,j] -2 * un[i,j]  + un[i-1,j]) + (nu * dt / dy**2) * (un[i,j+1] -2 * un[i,j]  + un[i,j-1])
    return 0

# %% [markdown]
# ## Numba accelerator

# %%
@njit(fastmath=True)
def solve_2d_diff_numba(u, un, nt, dt, dx, dy, nu):
    row, col = u.shape
    for n in range(nt):
        un= u.copy()
        for i in range(1, row-1): 
            for j in range(1,col-1):
                u[i,j] = un[i,j] + (nu * dt / dx**2) * (un[i+1,j] -2 * un[i,j]  + un[i-1,j]) + (nu * dt / dy**2) * (un[i,j+1] -2 * un[i,j]  + un[i,j-1])
    return 0

# %% [markdown]
# ## Pyccel accelerator

# %%
def solve_2d_diff_pyccel(u:'float[:]', un:'float[:]', nt:'int', dt:'float', dx:'float', dy:'float', nu:'float'):
    row, col = u.shape
    for n in range(nt):
        un = u.copy()
        for i in range(1, row-1): 
            for j in range(1,col-1):
                u[i,j] = un[i,j] + (nu * dt / dx**2) * (un[i+1,j] -2 * un[i,j]  + un[i-1,j]) + (nu * dt / dy**2) * (un[i,j+1] -2 * un[i,j]  + un[i,j-1])
    return 0

# %% [markdown]
# ## Inputs

# %%
###variable declarations
nt = 51
nx = 101
ny = 101
nu = .05
dx = 2 / (nx - 1)
dy = 2 / (ny - 1)
sigma = .25
dt = sigma * dx * dy / nu

x = np.linspace(0, 2, nx)
y = np.linspace(0, 2, ny)

u = np.ones((ny, nx))  # create a 1xn vector of 1's
un = np.ones((ny, nx))
    

solve_2d_diff_numba(u, un, nt, dt, dx, dy, nu)

fig = pyplot.figure(figsize=(7, 5), dpi=100)
ax = fig.gca(projection='3d')                      
X, Y = np.meshgrid(x, y)                            
surf = ax.plot_surface(X, Y, u, cmap=cm.viridis)
# Out:
# /tmp/ipykernel_20486/2025921710.py:21: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %% [markdown]
# ## Call Funtions

# %% [markdown]
# ### Pure function

# %%
# %timeit solve_2d_diff_pure(u, un, nt, dt, dx, dy, nu)
# Out:
# 1.71 s ± 115 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ### Function with numba accelerator

# %%
# %timeit solve_2d_diff_numba(u, un, nt, dt, dx, dy, nu)
# Out:
# 2.68 ms ± 104 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# ### Function with pyccel accelerator

# %%
solve_2d_diff_f90 = epyccel(solve_2d_diff_pyccel)
# Out:
# ERROR at annotation (semantic) stage
# pyccel:
#  |fatal [semantic]: mod_gnhb7s5jdz0f_gnhb7s5jdz0f.py [4,13]| Attribute copy not found
# ---------------------------------------------------------------------------
# PyccelSemanticError                       Traceback (most recent call last)
# /tmp/ipykernel_20486/2865422160.py in <module>
# ----> 1 solve_2d_diff_f90 = epyccel(solve_2d_diff_pyccel)
#
# ~/Documents/HPC/base/lib/python3.8/site-packages/pyccel/epyccel.py in epyccel(python_function_or_module, **kwargs)
#     331     # Serial version
#     332     else:
# --> 333         mod, fun = epyccel_seq( python_function_or_module, **kwargs )
#     334
#     335     # Return Fortran function (if any), otherwise module
#
# ~/Documents/HPC/base/lib/python3.8/site-packages/pyccel/epyccel.py in epyccel_seq(function_or_module, language, compiler, fflags, wrapper_flags, accelerators, verbose, debug, includes, libdirs, modules, libs, folder)
#     166         try:
#     167             # Generate shared library
# --> 168             execute_pyccel(pymod_filename,
#     169                            verbose       = verbose,
#     170                            language      = language,
#
# ~/Documents/HPC/base/lib/python3.8/site-packages/pyccel/codegen/pipeline.py in execute_pyccel(fname, syntax_only, semantic_only, convert_only, verbose, folder, language, compiler, fflags, wrapper_flags, includes, libdirs, modules, libs, debug, accelerators, output_name, compiler_export_file)
#     240         handle_error('annotation (semantic)')
#     241         # Raise a new error to avoid a large traceback
# --> 242         raise PyccelSemanticError('Semantic step failed') from None
#     243
#     244     if errors.has_errors():
#
# PyccelSemanticError: Semantic step failed

# %%
# %timeit solve_2d_diff_f90(u, un, nt, dt, dx, dy, nu)
